# %%
import os

def join_seq_sequences(list_fasta_seqs):
    output_names = det_fasta_names(list_fasta_seqs)
    for file in list_fasta_seqs:
        if '.fa' in 
            

def det_fasta_names(files_names):
    list_names = {}
    for file in files_names:
        if '.fa' in file:
            file_name = file[:file.find('0_75')-1] + '.fasta'
            list_names[file_name]
            
    list_names = list(set(list_names))
    return list_names
# Out:
#   File "<ipython-input-40-bacf2ea08c10>", line 8
#     def det_fasta_names(files_names):
#                                      ^
# IndentationError: expected an indented block

# %%
a = list(os.listdir())
print(det_fasta_names(a))
# Out:
# ['Parasteatodatepidariorum.fasta', 'Nephilaantipodiana.fasta', 'Leucaugevenusta_2.fasta', 'Leucaugevenusta.fasta', 'Steatodagrossa.fasta', 'Latrodectushesperus.fasta']

# %%
a = {}

# %%
a['0t'] = 5

# %%
a['0t'].
# Out:
# [1, 2, 3, 4, 5, 6, 9, 44]

# %%
10 not in a
# Out:
# True
