# %% [markdown]
# # Pseudocode

# %% [markdown]
# ## Input

# %% [markdown]
# target_organism = [target_id, target_name] #e.g [001, 'E. coli'] <br>
# peptide_family = [pep_family_id, family_name] <br>
# ptds_data =[peptide_id ,name ,dna_sequence, aa_sequence, reference_code,targets organisms_id, source_organism_id, peptide_family_id] <br>
# spiders_data = [spider_id, family, genus, specie, ... (taxonomic_data)] <br>
# transcriptomes_data = [id, reads, spider_id,reference_code,]

# %% [markdown]
# ## Process

# %% [markdown]
# ### Transcriptome data treatment

# %% [markdown]
# if transcriptomes_data[i] is assambly <br>
#   go to peptide search algorithm <br>
# else<br>
#   go to control quality <br>

# %% [markdown]
# #### Sequence control quality

# %% [markdown]
# mark repetides entries <br>
# check sequence quality __#definir umbral__ <br>

# %% [markdown]
# ### Peptides search algorithms

# %% [markdown]
# #### Peptide search option 1

# %% [markdown]
# cluster sequences __#definir parametros de agrupacion__<br>
# from clusters get contigs<br>
# from contigs get potential_code_regions <br>
# translate potential_code_regions <br>
# BLAST contigs against ptds_data[dna_sequence] <br>
# BLAST translated proteins against ptds_data[aa_sequence] <br>
# calculate physical chemestry properties [polarity, net charge, structure(alpha, beta)]

# %% [markdown]
# #### Peptide search option 2

# %% [markdown]
# cluster sequences #definir parametros de agrupacion <br>
# from clusters get contigs <br>
# from contigs get potential_code_regions <br>
# translate potential_code_regions <br>
# find signal_peptide <br>

# %% [markdown]
# ## Output

# %% [markdown]
# pept_predicted = {key:[dna_sequence(contig), predicted_protein, physical chemestry properties,Blast_peptide, blast_peptide_target_organism, blast_peptide_source]}
